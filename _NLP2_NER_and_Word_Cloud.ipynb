# %%
# !pip install -U spacy
# Out:
# Requirement already satisfied: spacy in /usr/local/lib/python3.12/dist-packages (3.8.11)
# Collecting spacy
#   Downloading spacy-3.8.13-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (28 kB)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.12/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.12/dist-packages (from spacy) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.12/dist-packages (from spacy) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.12/dist-packages (from spacy) (3.0.12)
# Collecting thinc<8.4.0,>=8.3.12 (from spacy)
#   Downloading thinc-8.3.13-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (14 kB)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.12/dist-packages (from spacy) (1.1.3)
# Collecting srsly<3.0.0,>=2.5.3 (from spacy)
#   Downloading srsly-2.5.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (19 kB)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.12/dist-packages (from spacy) (2.0.10)
# Collecting weasel<2.0.0,>=1.0.0 (from spacy)
#   Downloading weasel-1.0.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting confection<2.0.0,>=1.3.2 (from spacy)
#   Downloading confection-1.3.3-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from spacy) (0.24.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.12/dist-packages (from spacy) (4.67.3)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.12/dist-packages (from spacy) (2.0.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from spacy) (2.32.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from spacy) (2.12.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from spacy) (75.2.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from spacy) (26.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.0.0->spacy) (2.41.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.0.0->spacy) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2026.2.25)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from thinc<8.4.0,>=8.3.12->spacy) (1.3.3)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (0.0.4)
# Requirement already satisfied: cloudpathlib>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.23.0)
# Requirement already satisfied: smart-open>=5.2.1 in /usr/local/lib/python3.12/dist-packages (from weasel<2.0.0,>=1.0.0->spacy) (7.5.1)
# Requirement already satisfied: httpx>=0.24.0 in /usr/local/lib/python3.12/dist-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.28.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->spacy) (3.0.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (4.12.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (0.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer<1.0.0,>=0.3.0->spacy) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer<1.0.0,>=0.3.0->spacy) (2.19.2)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart-open>=5.2.1->weasel<2.0.0,>=1.0.0->spacy) (2.1.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Downloading spacy-3.8.13-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (33.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.2/33.2 MB 53.5 MB/s eta 0:00:00
# Downloading confection-1.3.3-py3-none-any.whl (35 kB)
# Downloading srsly-2.5.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 54.6 MB/s eta 0:00:00
# Downloading thinc-8.3.13-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 93.6 MB/s eta 0:00:00
# Downloading weasel-1.0.0-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 3.2 MB/s eta 0:00:00
# Installing collected packages: srsly, confection, thinc, weasel, spacy
#   Attempting uninstall: srsly
#     Found existing installation: srsly 2.5.2
#     Uninstalling srsly-2.5.2:
#       Successfully uninstalled srsly-2.5.2
#   Attempting uninstall: confection
#     Found existing installation: confection 0.1.5
#     Uninstalling confection-0.1.5:
#       Successfully uninstalled confection-0.1.5
#   Attempting uninstall: thinc
#     Found existing installation: thinc 8.3.10
#     Uninstalling thinc-8.3.10:
#       Successfully uninstalled thinc-8.3.10
#   Attempting uninstall: weasel
#     Found existing installation: weasel 0.4.3
#     Uninstalling weasel-0.4.3:
#       Successfully uninstalled weasel-0.4.3
#   Attempting uninstall: spacy
#     Found existing installation: spacy 3.8.11
#     Uninstalling spacy-3.8.11:
#       Successfully uninstalled spacy-3.8.11
# Successfully installed confection-1.3.3 spacy-3.8.13 srsly-2.5.3 thinc-8.3.13 weasel-1.0.0

# %%
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 44.1 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
# !python -m spacy download en_core_web_lg # install NER model
# Out:
# Collecting en-core-web-lg==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3.8.0/en_core_web_lg-3.8.0-py3-none-any.whl (400.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.7/400.7 MB 1.4 MB/s eta 0:00:00
# Installing collected packages: en-core-web-lg
# Successfully installed en-core-web-lg-3.8.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import spacy # contains model which we are going to use
from spacy import displacy # to display along with tag
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
nlp = spacy.load('en_core_web_lg') # To load or import NER model that already we have installed above
# en_core_web_lg is a spacy language model. It is more accurate, supports word vectors, entity linking, and is better at understanding context.

# %%
# we want NER (name entity recognition)
doc = nlp('Mr. Elon is going to acquire Twitter Inc of $45 billion in 2023') #Try 'Elon' only and then 'Elon Musk'

# %%
# ents - will display all entities doc.ents
doc.ents
# Out:
# (Elon, Twitter Inc of, $45 billion, 2023)

# %%
for i in doc.ents:
  print(i, '->', i.label_)
# Out:
# Elon -> PERSON
# Twitter Inc of -> ORG
# $45 billion -> MONEY
# 2023 -> DATE

# %% [markdown]
# Spacy library is not 100 % precise

# %%
# to display graphical representation for tags
displacy.render(doc,style='ent',jupyter=True) # ent - entity, In Jupyter instead of serve() try render()
# jupyter=True (this is optional in latest versions of spaCy) tells displacy to:
# Render the HTML visualization inline directly inside Jupyter Notebook or Google Colab and
# Without this, the visualization won’t appear properly in notebook environments.
# if you're using Jupyter Notebook or Google Colab, you should set jupyter=True.
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Mr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Elon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  is going to acquire
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Twitter Inc of
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $45 billion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2023
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </div></span>

# %%
df = pd.read_csv('apple.txt',on_bad_lines='skip') # to load txt file with read_csv() keep on_bad_lines='skip'

# %%
df # Reviews of customers on apple product
# Out:
#                                                     x
# 0   I recently bought a MacBook Air M1 and its per...
# 1   The MacBook Pro M2 is very fast and smooth for...
# 2   I love the design of Apple MacBook Air, it is ...
# 3   The Retina display on MacBook Pro is stunning ...
# 4   I had some keyboard issues but Apple fixed it ...
# 5    Apple laptops are expensive but worth the price.
# 6   The trackpad on MacBook is very smooth and res...
# 7   I use my MacBook Air for coding and machine le...
# 8     The speakers on MacBook Pro are loud and clear.
# 9   I faced heating issues during gaming on my Mac...
# 10          macOS is very smooth compared to Windows.
# 11  I switched from Windows to MacBook and I am ha...
# 12        The battery life of MacBook Air is amazing.
# 13  Some software compatibility issues exist on ma...
# 14     The build quality of Apple laptops is premium.
# 15  I use Final Cut Pro on MacBook Pro and it work...
# 16       The keyboard is comfortable for long typing.
# 17       Apple customer support is helpful and quick.
# 18             The laptop boots very fast due to SSD.
# 19               MacBook Air is perfect for students.
# 20   The performance of Apple M1 chip is outstanding.
# 21             MacBook Pro is best for professionals.
# 22        I like the aluminum body design of MacBook.
# 23                The screen brightness is very good.
# 24                The webcam quality could be better.
# 25     MacBook speakers are better than most laptops.
# 26          The touchpad gestures are very intuitive.
# 27            I use Xcode on MacBook for development.
# 28         The laptop is very reliable for daily use.
# 29              I love the battery backup of MacBook.
# 30         The design looks very premium and elegant.
# 31    The price is high but performance is top-notch.
# 32           MacBook Pro handles multitasking easily.
# 33        I enjoy watching movies on MacBook display.
# 34                         The fan noise is very low.
# 35           MacBook Air is very silent during usage.
# 36        I use my MacBook for data science projects.
# 37              The macOS interface is user-friendly.
# 38            The laptop is durable and long-lasting.
# 39  Overall, Apple laptops provide great user expe...

# %%
df.iloc[0] # will extract 0 index row
# Out:
# x    I recently bought a MacBook Air M1 and its per...
# Name: 0, dtype: object

# %%
df['x']# x is a column name
# Out:
# 0     I recently bought a MacBook Air M1 and its per...
# 1     The MacBook Pro M2 is very fast and smooth for...
# 2     I love the design of Apple MacBook Air, it is ...
# 3     The Retina display on MacBook Pro is stunning ...
# 4     I had some keyboard issues but Apple fixed it ...
# 5      Apple laptops are expensive but worth the price.
# 6     The trackpad on MacBook is very smooth and res...
# 7     I use my MacBook Air for coding and machine le...
# 8       The speakers on MacBook Pro are loud and clear.
# 9     I faced heating issues during gaming on my Mac...
# 10            macOS is very smooth compared to Windows.
# 11    I switched from Windows to MacBook and I am ha...
# 12          The battery life of MacBook Air is amazing.
# 13    Some software compatibility issues exist on ma...
# 14       The build quality of Apple laptops is premium.
# 15    I use Final Cut Pro on MacBook Pro and it work...
# 16         The keyboard is comfortable for long typing.
# 17         Apple customer support is helpful and quick.
# 18               The laptop boots very fast due to SSD.
# 19                 MacBook Air is perfect for students.
# 20     The performance of Apple M1 chip is outstanding.
# 21               MacBook Pro is best for professionals.
# 22          I like the aluminum body design of MacBook.
# 23                  The screen brightness is very good.
# 24                  The webcam quality could be better.
# 25       MacBook speakers are better than most laptops.
# 26            The touchpad gestures are very intuitive.
# 27              I use Xcode on MacBook for development.
# 28           The laptop is very reliable for daily use.
# 29                I love the battery backup of MacBook.
# 30           The design looks very premium and elegant.
# 31      The price is high but performance is top-notch.
# 32             MacBook Pro handles multitasking easily.
# 33          I enjoy watching movies on MacBook display.
# 34                           The fan noise is very low.
# 35             MacBook Air is very silent during usage.
# 36          I use my MacBook for data science projects.
# 37                The macOS interface is user-friendly.
# 38              The laptop is durable and long-lasting.
# 39    Overall, Apple laptops provide great user expe...
# Name: x, dtype: object

# %%
# To see index 0 row completely:
pd.set_option('display.max_colwidth',None)
# max_colwidth: will display all text in col., max_rows: to display all rows, None: Display all

# %%
df
# Out:
#                                                                           x
# 0      I recently bought a MacBook Air M1 and its performance is excellent.
# 1             The MacBook Pro M2 is very fast and smooth for video editing.
# 2   I love the design of Apple MacBook Air, it is lightweight and portable.
# 3                  The Retina display on MacBook Pro is stunning and sharp.
# 4             I had some keyboard issues but Apple fixed it with an update.
# 5                          Apple laptops are expensive but worth the price.
# 6                    The trackpad on MacBook is very smooth and responsive.
# 7                     I use my MacBook Air for coding and machine learning.
# 8                           The speakers on MacBook Pro are loud and clear.
# 9                       I faced heating issues during gaming on my MacBook.
# 10                                macOS is very smooth compared to Windows.
# 11                       I switched from Windows to MacBook and I am happy.
# 12                              The battery life of MacBook Air is amazing.
# 13                       Some software compatibility issues exist on macOS.
# 14                           The build quality of Apple laptops is premium.
# 15                   I use Final Cut Pro on MacBook Pro and it works great.
# 16                             The keyboard is comfortable for long typing.
# 17                             Apple customer support is helpful and quick.
# 18                                   The laptop boots very fast due to SSD.
# 19                                     MacBook Air is perfect for students.
# 20                         The performance of Apple M1 chip is outstanding.
# 21                                   MacBook Pro is best for professionals.
# 22                              I like the aluminum body design of MacBook.
# 23                                      The screen brightness is very good.
# 24                                      The webcam quality could be better.
# 25                           MacBook speakers are better than most laptops.
# 26                                The touchpad gestures are very intuitive.
# 27                                  I use Xcode on MacBook for development.
# 28                               The laptop is very reliable for daily use.
# 29                                    I love the battery backup of MacBook.
# 30                               The design looks very premium and elegant.
# 31                          The price is high but performance is top-notch.
# 32                                 MacBook Pro handles multitasking easily.
# 33                              I enjoy watching movies on MacBook display.
# 34                                               The fan noise is very low.
# 35                                 MacBook Air is very silent during usage.
# 36                              I use my MacBook for data science projects.
# 37                                    The macOS interface is user-friendly.
# 38                                  The laptop is durable and long-lasting.
# 39                    Overall, Apple laptops provide great user experience.

# %%
# how to convert these tabular sentences to paragraph for a corpus?
# we want to join all these sentences.

# %%
# joining all sentences of dataset
txt = ' '.join(df['x']) # with space join all sentences in x
txt
# Out:
# 'I recently bought a MacBook Air M1 and its performance is excellent. The MacBook Pro M2 is very fast and smooth for video editing. I love the design of Apple MacBook Air, it is lightweight and portable. The Retina display on MacBook Pro is stunning and sharp. I had some keyboard issues but Apple fixed it with an update. Apple laptops are expensive but worth the price. The trackpad on MacBook is very smooth and responsive. I use my MacBook Air for coding and machine learning. The speakers on MacBook Pro are loud and clear. I faced heating issues during gaming on my MacBook. macOS is very smooth compared to Windows. I switched from Windows to MacBook and I am happy. The battery life of MacBook Air is amazing. Some software compatibility issues exist on macOS. The build quality of Apple laptops is premium. I use Final Cut Pro on MacBook Pro and it works great. The keyboard is comfortable for long typing. Apple customer support is helpful and quick. The laptop boots very fast due to SSD. MacBook Air is perfect for students. The performance of Apple M1 chip is outstanding. MacBook Pro is best for professionals. I like the aluminum body design of MacBook. The screen brightness is very good. The webcam quality could be better. MacBook speakers are better than most laptops. The touchpad gestures are very intuitive. I use Xcode on MacBook for development. The laptop is very reliable for daily use. I love the battery backup of MacBook. The design looks very premium and elegant. The price is high but performance is top-notch. MacBook Pro handles multitasking easily. I enjoy watching movies on MacBook display. The fan noise is very low. MacBook Air is very silent during usage. I use my MacBook for data science projects. The macOS interface is user-friendly. The laptop is durable and long-lasting. Overall, Apple laptops provide great user experience.'

# %%
x = nlp(txt)

# %%
displacy.render(x,style='ent') # 70 tp 80% accurate model
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">I recently bought a
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     MacBook Air M1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  and its performance is excellent.
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The MacBook Pro M2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
#  is very fast and smooth for video editing. I love the design of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple MacBook Air
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , it is lightweight and portable. The Retina display on
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     MacBook Pro
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is stunning and sharp. I had some keyboard issues but
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  fixed it with an update.
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  laptops are expensive but worth the price. The trackpad on
# <mark class="entity" style="background: #9cc9cc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     MacBook
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
#  is very smooth and responsive. I use my
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     MacBook Air
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  for coding and machine learning. The speakers on
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     MacBook Pro
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  are loud and clear. I faced heating issues during gaming on my
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     MacBook
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# . macOS is very smooth compared to Windows. I switched from
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Windows
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  to
# <mark class="entity" style="background: #9cc9cc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     MacBook
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
#  and I am happy. The battery life of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     MacBook Air
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is amazing. Some software compatibility issues exist on macOS. The build quality of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  laptops is premium. I use Final Cut Pro on MacBook Pro and it works great. The keyboard is comfortable for long typing.
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  customer support is helpful and quick. The laptop boots very fast due to
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SSD
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# .
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     MacBook Air
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is perfect for students. The performance of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple M1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  chip is outstanding.
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     MacBook Pro
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is best for professionals. I like the aluminum body design of
# <mark class="entity" style="background: #9cc9cc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     MacBook
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
# . The screen brightness is very good. The webcam quality could be better.
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     MacBook
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  speakers are better than most laptops. The touchpad gestures are very intuitive. I use
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Xcode
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  on
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.

# %% [markdown]
# # **Word Cloud**

# %%
#!pip install WordCloud
from wordcloud import WordCloud,STOPWORDS
import matplotlib.pyplot as plt

# %% [markdown]
# A word cloud is a visualization technique for text data where the most frequent word is shown in the biggest font size.
#
#
# You can create Customized Word Cloud in python. Refer documentation

# %%
wc = WordCloud(background_color='grey').generate(txt)
plt.imshow(wc)#image show
plt.axis('off')
plt.title("Apple Laptop Reviews",size=25)
# bigger the name of word more the frequency of that word in that corpus
# font of apple, laptop is huge i.e. it is occuring many times in text
# word cloud is important when we are analysing the data when we build Naive bias text classification.
# This is how we can create word cloud
# Out:
# Text(0.5, 1.0, 'Apple Laptop Reviews')

# %% [markdown]
# How to build an NLP pipeline
#
# Step1: Sentence Segmentation
# Sentence Segment is the first step for building the NLP pipeline. It breaks the paragraph into separate sentences.
#
# Step2: Word Tokenization
# Word Tokenizer is used to break the sentence into separate words or tokens.
#
# Step3: Stemming
# Stemming is used to normalize words into its base form or root form. For example, celebrates, celebrated and celebrating, all these words are originated with a single root word "celebrate." The big problem with stemming is that sometimes it produces the root word which may not have any meaning.
#
# Step 4: Lemmatization
# Lemmatization is quite similar to the Stemming. It is used to group different inflected forms of the word, called Lemma. The main difference between Stemming and lemmatization is that it produces the root word, which has a meaning.
#
# Step 5: Identifying Stop Words
# In English, there are a lot of words that appear very frequently like "is", "and", "the", and "a". NLP pipelines will flag these words as stop words. Stop words might be filtered out before doing any statistical analysis.
#
# Step 6: Dependency Parsing
# Dependency Parsing is used to find that how all the words in the sentence are related to each other.
#
# Step 7: POS tags
# POS stands for parts of speech, which includes Noun, verb, adverb, and Adjective. It indicates that how a word functions with its meaning as well as grammatically within the sentences. A word has one or more parts of speech based on the context in which it is used.
#
# Step 8: Named Entity Recognition (NER)
# Named Entity Recognition (NER) is the process of detecting the named entity such as person name, movie name, organization name, or location.
