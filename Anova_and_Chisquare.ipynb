# %% [markdown]
# # Anova - Analysis of Variance

# %% [markdown]
# <img src="https://s3.amazonaws.com/assets.datacamp.com/blog_assets/Machine+Learning+R/iris-machinelearning.png" alt="Iris dataset" width="600" height="150">

# %%
import pandas as pd
df = pd.read_csv('/content/Iris_Anova.csv')
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  target
# 0              5.1           3.5            1.4           0.2       0
# 1              4.9           3.0            1.4           0.2       0
# 2              4.7           3.2            1.3           0.2       0
# 3              4.6           3.1            1.5           0.2       0
# 4              5.0           3.6            1.4           0.2       0
# ..             ...           ...            ...           ...     ...
# 145            6.7           3.0            5.2           2.3       2
# 146            6.3           2.5            5.0           1.9       2
# 147            6.5           3.0            5.2           2.0       2
# 148            6.2           3.4            5.4           2.3       2
# 149            5.9           3.0            5.1           1.8       2
#
# [150 rows x 5 columns]

# %%
df['target'].value_counts()
# Out:
# target
# 0    50
# 1    50
# 2    50
# Name: count, dtype: int64

# %%
df.iloc[:,1]
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: SepalWidthCm, Length: 150, dtype: float64

# %%
df[df['target']==0]
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  target
# 0             5.1           3.5            1.4           0.2       0
# 1             4.9           3.0            1.4           0.2       0
# 2             4.7           3.2            1.3           0.2       0
# 3             4.6           3.1            1.5           0.2       0
# 4             5.0           3.6            1.4           0.2       0
# 5             5.4           3.9            1.7           0.4       0
# 6             4.6           3.4            1.4           0.3       0
# 7             5.0           3.4            1.5           0.2       0
# 8             4.4           2.9            1.4           0.2       0
# 9             4.9           3.1            1.5           0.1       0
# 10            5.4           3.7            1.5           0.2       0
# 11            4.8           3.4            1.6           0.2       0
# 12            4.8           3.0            1.4           0.1       0
# 13            4.3           3.0            1.1           0.1       0
# 14            5.8           4.0            1.2           0.2       0
# 15            5.7           4.4            1.5           0.4       0
# 16            5.4           3.9            1.3           0.4       0
# 17            5.1           3.5            1.4           0.3       0
# 18            5.7           3.8            1.7           0.3       0
# 19            5.1           3.8            1.5           0.3       0
# 20            5.4           3.4            1.7           0.2       0
# 21            5.1           3.7            1.5           0.4       0
# 22            4.6           3.6            1.0           0.2       0
# 23            5.1           3.3            1.7           0.5       0
# 24            4.8           3.4            1.9           0.2       0
# 25            5.0           3.0            1.6           0.2       0
# 26            5.0           3.4            1.6           0.4       0
# 27            5.2           3.5            1.5           0.2       0
# 28            5.2           3.4            1.4           0.2       0
# 29            4.7           3.2            1.6           0.2       0
# 30            4.8           3.1            1.6           0.2       0
# 31            5.4           3.4            1.5           0.4       0
# 32            5.2           4.1            1.5           0.1       0
# 33            5.5           4.2            1.4           0.2       0
# 34            4.9           3.1            1.5           0.1       0
# 35            5.0           3.2            1.2           0.2       0
# 36            5.5           3.5            1.3           0.2       0
# 37            4.9           3.1            1.5           0.1       0
# 38            4.4           3.0            1.3           0.2       0
# 39            5.1           3.4            1.5           0.2       0
# 40            5.0           3.5            1.3           0.3       0
# 41            4.5           2.3            1.3           0.3       0
# 42            4.4           3.2            1.3           0.2       0
# 43            5.0           3.5            1.6           0.6       0
# 44            5.1           3.8            1.9           0.4       0
# 45            4.8           3.0            1.4           0.3       0
# 46            5.1           3.8            1.6           0.2       0
# 47            4.6           3.2            1.4           0.2       0
# 48            5.3           3.7            1.5           0.2       0
# 49            5.0           3.3            1.4           0.2       0

# %%
df[df['target']==1]
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 125            7.2           3.2            6.0           1.8       2
# 126            6.2           2.8            4.8           1.8       2
# 127            6.1           3.0            4.9           1.8       2
# 128            6.4           2.8            5.6           2.1       2
# 129            7.2           3.0            5.8           1.6       2
# 130            7.4           2.8            6.1           1.9       2
# 131            7.9           3.8            6.4           2.0       2
# 132            6.4           2.8            5.6           2.2       2
# 133            6.3           2.8            5.1           1.5       2
# 134            6.1           2.6            5.6           1.4       2
# 135            7.7           3.0            6.1           2.3       2
# 136            6.3           3.4            5.6           2.4       2
# 137            6.4           3.1            5.5           1.8       2
# 138            6.0           3.0            4.8           1.8       2
# 139            6.9           3.1            5.4           2.1       2
# 140            6.7           3.1            5.6           2.4       2
# 141            6.9           3.1            5.1           2.3       2
# 142            5.8           2.7            5.1           1.9       2
# 143            6.8           3.2            5.9           2.3       2
# 144            6.7           3.3            5.7           2.5       2
# 145            6.7           3.0            5.2           2.3       2
# 146            6.3           2.5            5.0           1.9       2
# 147            6.5           3.0            5.2           2.0       2
# 148            6.2           3.4            5.4           2.3       2
# 149            5.9           3.0            5.1           1.8       2

# %%
df[df['target']==0]['SepalWidthCm']
# Out:
# 0     3.5
# 1     3.0
# 2     3.2
# 3     3.1
# 4     3.6
# 5     3.9
# 6     3.4
# 7     3.4
# 8     2.9
# 9     3.1
# 10    3.7
# 11    3.4
# 12    3.0
# 13    3.0
# 14    4.0
# 15    4.4
# 16    3.9
# 17    3.5
# 18    3.8
# 19    3.8
# 20    3.4
# 21    3.7
# 22    3.6
# 23    3.3
# 24    3.4
# 25    3.0
# 26    3.4
# 27    3.5
# 28    3.4
# 29    3.2
# 30    3.1
# 31    3.4
# 32    4.1
# 33    4.2
# 34    3.1
# 35    3.2
# 36    3.5
# 37    3.1
# 38    3.0
# 39    3.4
# 40    3.5
# 41    2.3
# 42    3.2
# 43    3.5
# 44    3.8
# 45    3.0
# 46    3.8
# 47    3.2
# 48    3.7
# 49    3.3
# Name: SepalWidthCm, dtype: float64

# %%
df[df['target']==1]['SepalWidthCm']
# Out:
# 50    3.2
# 51    3.2
# 52    3.1
# 53    2.3
# 54    2.8
# 55    2.8
# 56    3.3
# 57    2.4
# 58    2.9
# 59    2.7
# 60    2.0
# 61    3.0
# 62    2.2
# 63    2.9
# 64    2.9
# 65    3.1
# 66    3.0
# 67    2.7
# 68    2.2
# 69    2.5
# 70    3.2
# 71    2.8
# 72    2.5
# 73    2.8
# 74    2.9
# 75    3.0
# 76    2.8
# 77    3.0
# 78    2.9
# 79    2.6
# 80    2.4
# 81    2.4
# 82    2.7
# 83    2.7
# 84    3.0
# 85    3.4
# 86    3.1
# 87    2.3
# 88    3.0
# 89    2.5
# 90    2.6
# 91    3.0
# 92    2.6
# 93    2.3
# 94    2.7
# 95    3.0
# 96    2.9
# 97    2.9
# 98    2.5
# 99    2.8
# Name: SepalWidthCm, dtype: float64

# %%
df[df['target']==2]['SepalWidthCm']
# Out:
# 100    3.3
# 101    2.7
# 102    3.0
# 103    2.9
# 104    3.0
# 105    3.0
# 106    2.5
# 107    2.9
# 108    2.5
# 109    3.6
# 110    3.2
# 111    2.7
# 112    3.0
# 113    2.5
# 114    2.8
# 115    3.2
# 116    3.0
# 117    3.8
# 118    2.6
# 119    2.2
# 120    3.2
# 121    2.8
# 122    2.8
# 123    2.7
# 124    3.3
# 125    3.2
# 126    2.8
# 127    3.0
# 128    2.8
# 129    3.0
# 130    2.8
# 131    3.8
# 132    2.8
# 133    2.8
# 134    2.6
# 135    3.0
# 136    3.4
# 137    3.1
# 138    3.0
# 139    3.1
# 140    3.1
# 141    3.1
# 142    2.7
# 143    3.2
# 144    3.3
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: SepalWidthCm, dtype: float64

# %%
df.columns
# Out:
# Index(['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'target'],
#       dtype='object')

# %%
group1_setosa = df[df['target']==0]['SepalWidthCm']
group2_versicolor =df[df['target']==1]['SepalWidthCm']
group3_virginica = df[df['target']==2]['SepalWidthCm']

# %%
group1_setosa.mean(),group2_versicolor.mean(),group3_virginica.mean()
#mean of sepal width of all 3 categories.
# Out:
# (np.float64(3.418), np.float64(2.7700000000000005), np.float64(2.974))

# %%
import seaborn as sns
sns.displot(data=df,
            x='SepalWidthCm',
            hue='target',
            fill=True,
            kind='kde',
            palette=['Orange','Green','Blue'])

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,4))
plt.scatter(range(1,51),group1_setosa)
plt.scatter(range(1,51),group2_versicolor)
plt.scatter(range(1,51),group3_virginica)

plt.legend(df.target.unique())
plt.show()

# %%
# f_oneway - one way ANOVA
from scipy import stats
stats.f_oneway(group1_setosa,group2_versicolor,group3_virginica)
# p-value is 4.49*10^-17 which is approximately equal to 0. so p<alfa.
# so reject null hypo. So interpretation: at least 1 of them is different. i.e. setosa is different.
# Out:
# F_onewayResult(statistic=np.float64(47.36446140299382), pvalue=np.float64(1.3279165184572242e-16))

# %%
# another example of one way ANOVA
df1=pd.read_csv('/content/Iris_Anova.csv')
stats.f_oneway(df1.iloc[:,0],df1.iloc[:,1],df1.iloc[:,2],df1.iloc[:,3])
# p = 4.66 * 10^-159 which is approximately = 0. So reject null hypo.
# H0=MUsl = MUsw = MUpl = MUpw, Ha = at least one of them is different
# Out:
# F_onewayResult(statistic=np.float64(483.57128302425957), pvalue=np.float64(3.4996987081939704e-159))

# %% [markdown]
# # Chi-Square Test

# %%
from scipy.stats import chi2_contingency
from matplotlib import pyplot as plt
import pandas as pd

# %%
# Athlet and Smoker example: These are observed frequencies\
data = [[14,4],[0,10]]
data
# Out:
# [[14, 4], [0, 10]]

# %%
df=pd.DataFrame(data,
                index=['Athlete','non-Athlete'],  # row names
                columns=['non-smokers','smokers'])  # column names

# %%
df
# Out:
#              non-smokers  smokers
# Athlete               14        4
# non-Athlete            0       10

# %%
df.plot(kind='bar')
# Out:
# <Axes: >

# %%
chi2_contingency(data)
# Out:
# Chi2ContingencyResult(statistic=np.float64(12.600000000000001), pvalue=np.float64(0.0003857467556820071), dof=1, expected_freq=array([[9., 9.],
#        [5., 5.]]))

# %%
Chi2,p,dof,exp = chi2_contingency(data)  # test statistic, p-value,df,expected frequency
# p-value 0.00038 < 0.05 so reject null hypothesis (H0:both variables are indepedendent). Accept Ha: Both variables are dependent

# %%
Chi2
# Out:
# np.float64(12.600000000000001)

# %%
p
# Out:
# np.float64(0.0003857467556820071)

# %%
dof
# Out:
# 1

# %%
exp
# Out:
# array([[9., 9.],
#        [5., 5.]])

# %%
a=0.5
if p<a:
  print("Reject null hypothesis. Smoking and being Athlete are dependent on each other.")
else:
  print("Accept null hypothesis. Smoking and being Athlete are not dependent on each other.")
# Out:
# Reject null hypothesis. Smoking and being Athlete are dependent on each other.
